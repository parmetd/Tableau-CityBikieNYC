# %% [markdown]
# # Initializing Data

# %% [markdown]
# The goal is to merge 3 CitibikeNYC datasets into one so it can be loaded into Tableau.

# %%
#dependencies
import pandas as pd

# %%
#files to load
Jan2019_df = pd.read_csv('./data/201901-citibike-tripdata.csv')
Feb2019_df = pd.read_csv('./data/201902-citibike-tripdata.csv')
Mar2019_df = pd.read_csv('./data/201903-citibike-tripdata.csv')
Jan2019_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1           316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2           591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3          2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4           303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#    start station id           start station name  start station latitude  \
# 0            3160.0  Central Park West & W 76 St               40.778968
# 1             519.0        Pershing Square North               40.751873
# 2            3171.0      Amsterdam Ave & W 82 St               40.785247
# 3             504.0              1 Ave & E 16 St               40.732219
# 4             229.0               Great Jones St               40.727434
#
#    start station longitude  end station id        end station name  \
# ...

# %%
Feb2019_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3           478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4           225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
Mar2019_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1463  2019-03-01 00:00:16.0970  2019-03-01 00:24:39.3880
# 1           285  2019-03-01 00:00:32.3850  2019-03-01 00:05:18.1830
# 2           686  2019-03-01 00:00:47.7970  2019-03-01 00:12:14.3090
# 3           442  2019-03-01 00:01:01.2090  2019-03-01 00:08:23.7510
# 4          2913  2019-03-01 00:01:09.2810  2019-03-01 00:49:42.3810
#
#    start station id    start station name  start station latitude  \
# 0             319.0  Fulton St & Broadway               40.711066
# 1             439.0        E 4 St & 2 Ave               40.726281
# 2             526.0       E 33 St & 5 Ave               40.747659
# 3            3474.0     6 Ave & Spring St               40.725256
# 4             379.0       W 31 St & 7 Ave               40.749156
#
#    start station longitude  end station id             end station name  \
# 0               -74.009447           347.0  Greenwich St & W Houston St
# ...

# %%
Jan2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967287 entries, 0 to 967286
# Data columns (total 15 columns):
# tripduration               967287 non-null int64
# starttime                  967287 non-null object
# stoptime                   967287 non-null object
# start station id           967269 non-null float64
# start station name         967269 non-null object
# start station latitude     967287 non-null float64
# start station longitude    967287 non-null float64
# end station id             967269 non-null float64
# end station name           967269 non-null object
# end station latitude       967287 non-null float64
# end station longitude      967287 non-null float64
# bikeid                     967287 non-null int64
# usertype                   967287 non-null object
# birth year                 967287 non-null int64
# gender                     967287 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 110.7+ MB

# %%
Feb2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943744 entries, 0 to 943743
# Data columns (total 15 columns):
# tripduration               943744 non-null int64
# starttime                  943744 non-null object
# stoptime                   943744 non-null object
# start station id           943735 non-null float64
# start station name         943735 non-null object
# start station latitude     943744 non-null float64
# start station longitude    943744 non-null float64
# end station id             943735 non-null float64
# end station name           943735 non-null object
# end station latitude       943744 non-null float64
# end station longitude      943744 non-null float64
# bikeid                     943744 non-null int64
# usertype                   943744 non-null object
# birth year                 943744 non-null int64
# gender                     943744 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 108.0+ MB

# %%
Mar2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1327960 entries, 0 to 1327959
# Data columns (total 15 columns):
# tripduration               1327960 non-null int64
# starttime                  1327960 non-null object
# stoptime                   1327960 non-null object
# start station id           1327950 non-null float64
# start station name         1327950 non-null object
# start station latitude     1327960 non-null float64
# start station longitude    1327960 non-null float64
# end station id             1327950 non-null float64
# end station name           1327950 non-null object
# end station latitude       1327960 non-null float64
# end station longitude      1327960 non-null float64
# bikeid                     1327960 non-null int64
# usertype                   1327960 non-null object
# birth year                 1327960 non-null int64
# gender                     1327960 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 152.0+ MB

# %%
df = Feb2019_df.append(Jan2019_df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1911031 entries, 0 to 967286
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  object
# stoptime                   object
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 233.3+ MB

# %%
Q1_2019_df = df.append(Mar2019_df)
Q1_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3238991 entries, 0 to 1327959
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  object
# stoptime                   object
# start station id           float64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 int64
# gender                     int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 395.4+ MB

# %%
Q1_2019_df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.238991e+06      3.238954e+06            3.238991e+06
# mean   8.280649e+02      1.638180e+03            4.073747e+01
# std    7.861383e+03      1.461994e+03            3.037575e-02
# min    6.100000e+01      7.200000e+01            4.065540e+01
# 25%    3.150000e+02      3.830000e+02            4.071871e+01
# 50%    5.220000e+02      5.090000e+02            4.073913e+01
# 75%    8.950000e+02      3.284000e+03            4.075725e+01
# max    2.969781e+06      3.749000e+03            4.086600e+01
#
#        start station longitude  end station id  end station latitude  \
# count             3.238991e+06    3.238954e+06          3.238991e+06
# mean             -7.398207e+01    1.627446e+03          4.073730e+01
# std               1.868030e-02    1.460845e+03          3.016513e-02
# min              -7.401713e+01    7.200000e+01          4.065540e+01
# ...

# %%
Q1_2019_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3           478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4           225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
Q1_2019_df.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 1327955           351  2019-03-31 23:59:30.5850  2019-04-01 00:05:21.7850
# 1327956          1943  2019-03-31 23:59:55.3410  2019-04-01 00:32:18.6920
# 1327957           515  2019-03-31 23:59:50.1810  2019-04-01 00:08:25.8330
# 1327958           660  2019-03-31 23:59:56.6520  2019-04-01 00:10:57.3760
# 1327959           132  2019-03-31 23:59:58.0230  2019-04-01 00:02:10.5920
#
#          start station id        start station name  start station latitude  \
# 1327955            3747.0           E 84 St & 3 Ave               40.777554
# 1327956             450.0           W 49 St & 8 Ave               40.762272
# 1327957            3542.0  Amsterdam Ave & W 119 St               40.808625
# 1327958            3434.0    W 88 St & West End Ave               40.790254
# 1327959             393.0         E 5 St & Avenue C               40.722992
#
#          start station longitude  end station id  \
# ...

# %%
Q1_2019_df.to_csv('./data/Q1_2019.csv')
